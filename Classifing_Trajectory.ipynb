# %%
#pip install dollarpy
# Out:
# Collecting dollarpyNote: you may need to restart the kernel to use updated packages.
#
#   Using cached dollarpy-0.1.1-py2.py3-none-any.whl (3.7 kB)
# Installing collected packages: dollarpy
# Successfully installed dollarpy-0.1.1

# %%
#pip install mediapipe
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.0-cp39-cp39-win_amd64.whl (50.2 MB)
# Collecting protobuf<4,>=3.11
#   Using cached protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
# Collecting numpy
#   Using cached numpy-1.24.3-cp39-cp39-win_amd64.whl (14.9 MB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (from mediapipe) (22.1.0)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.7.0.72-cp37-abi3-win_amd64.whl (44.9 MB)
# Collecting sounddevice>=0.4.4
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Collecting absl-py
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.5.9-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrew\appdata\roaming\python\python39\site-packages (from matplotlib->mediapipe) (23.0)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.5.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andrew\appdata\roaming\python\python39\site-packages (from matplotlib->mediapipe) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.4-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.0 MB 1.3 MB/s eta 0:00:02
#      - -------------------------------------- 0.1/2.0 MB 812.7 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/2.0 MB 737.3 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/2.0 MB 853.3 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.2/2.0 MB 958.4 kB/s eta 0:00:02
#      ----- ---------------------------------- 0.3/2.0 MB 1.1 MB/s eta 0:00:02
#      ------- -------------------------------- 0.4/2.0 MB 1.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.5/2.0 MB 1.3 MB/s eta 0:00:02
#      ----------- ---------------------------- 0.6/2.0 MB 1.4 MB/s eta 0:00:01
#      ------------ --------------------------- 0.6/2.0 MB 1.4 MB/s eta 0:00:01
#      -------------- ------------------------- 0.7/2.0 MB 1.4 MB/s eta 0:00:01
#      ------------------ --------------------- 0.9/2.0 MB 1.7 MB/s eta 0:00:01
#      --------------------- ------------------ 1.0/2.0 MB 1.8 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.2/2.0 MB 1.8 MB/s eta 0:00:01
#      ------------------------- -------------- 1.2/2.0 MB 1.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.4/2.0 MB 1.9 MB/s eta 0:00:01
#      ------------------------------ --------- 1.5/2.0 MB 1.9 MB/s eta 0:00:01
#      -------------------------------- ------- 1.6/2.0 MB 2.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 1.7/2.0 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 1.8/2.0 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 2.0 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: pycparser in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andrew\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\andrew\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: flatbuffers, pyparsing, protobuf, pillow, numpy, kiwisolver, importlib-resources, fonttools, cycler, absl-py, sounddevice, opencv-contrib-python, contourpy, matplotlib, mediapipe
# Successfully installed absl-py-1.4.0 contourpy-1.0.7 cycler-0.11.0 flatbuffers-23.5.9 fonttools-4.39.4 importlib-resources-5.12.0 kiwisolver-1.4.4 matplotlib-3.7.1 mediapipe-0.10.0 numpy-1.24.3 opencv-contrib-python-4.7.0.72 pillow-9.5.0 protobuf-3.20.3 pyparsing-3.0.9 sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (from opencv-python) (1.24.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72

# %%
#pip install playsound
# Out:
# Collecting playsound
#   Using cached playsound-1.3.0-py3-none-any.whl
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install numpy scipy
# Out:
# Requirement already satisfied: numpy in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (1.24.3)
# Requirement already satisfied: scipy in c:\users\andrew\anaconda3\envs\hci\lib\site-packages (1.10.1)

# %%
import dollarpy as dp
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
import csv
from dollarpy import Point , Recognizer , Template 
import os
import numpy as np
import matplotlib.pyplot as plt
from playsound import playsound
import threading

# %%
mp_holistic=mp.solutions.holistic

# %%
def getPoint(vidPath):
  with mp_holistic.Holistic (static_image_mode=True ,
              min_detection_confidence=0.3,min_tracking_confidence=0.5) as holisitc :
    #right_shoulder=[]
    #left_shoulder=[]
    right_wrist=[]
    left_wrist=[]
    right_elbow=[]
    left_elbow=[]
    left_heel=[]
    right_heel=[]
    left_foot=[]
    right_foot=[]
    points=[]
    
    
    video = cv2.VideoCapture(vidPath)
    while video.isOpened():
        ret, frame = video.read()

        # Recolor Feed
        if ret==True:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        

            results = holisitc.process((image))
            if results.pose_landmarks:
                right_hand_landmarks = results.right_hand_landmarks
                left_hand_landmarks = results.left_hand_landmarks

                if right_hand_landmarks:
                    for landmark in right_hand_landmarks.landmark:
                        right_wrist.append(Point(landmark.x, landmark.y, 1))

                if left_hand_landmarks:
                    for landmark in left_hand_landmarks.landmark:
                        left_wrist.append(Point(landmark.x, landmark.y, 2))
                    
#               right_elbow.append(
#                 Point(results.pose_landmarks.landmark[14].x,
#                       results.pose_landmarks.landmark[14].y,
#                       3)
#                 )
#               left_elbow.append(
#                 Point(results.pose_landmarks.landmark[13].x,
#                       results.pose_landmarks.landmark[13].y,
#                       4)
#                )
#               right_heel.append(
#                 Point(results.pose_landmarks.landmark[30].x,
#                       results.pose_landmarks.landmark[30].y,
#                       5)
#                 )
#               left_heel.append(
#                 Point(results.pose_landmarks.landmark[29].x,
#                       results.pose_landmarks.landmark[29].y,
#                       6)
#                )
#               right_foot.append(
#                 Point(results.pose_landmarks.landmark[32].x,
#                       results.pose_landmarks.landmark[32].y,
#                       7)
#                 )
#               left_foot.append(
#                 Point(results.pose_landmarks.landmark[31].x,
#                       results.pose_landmarks.landmark[31].y,
#                       8)
               
               
        else :
          break   
    points = right_wrist + left_wrist + right_elbow + left_elbow + right_heel + left_heel + right_foot + left_foot
    return points

# %%
classes=[]

# %%
pth = "C://Users//Andrew//Downloads//HCI_Project//M_1.mp4" #path of video 
points = getPoint(pth)
tmp = Template("Right_Hand_Detection",points)
classes.append(tmp)

# %%
pth = "C://Users//Andrew//Downloads//HCI_Project//M_2.mp4" #path of video 
points = getPoint(pth)
tmp = Template("Left_Hand_Detection",points)
classes.append(tmp)

# %%
print(classes)
# Out:
stroke 1, (0.37166500091552734, 0.38900071382522583), stroke 1, (0.4133734703063965, 0.3616785407066345), stroke 1, (0.41130366921424866, 0.3317703604698181), stroke 1, (0.3780865967273712, 0.32131773233413696), stroke 1, (0.38382232189178467, 0.2952909767627716), stroke 1, (0.3940425515174866, 0.2498129904270172), stroke 1, (0.40464526414871216, 0.2765079736709595), stroke 1, (0.40030181407928467, 0.2995450496673584), stroke 1, (0.35218584537506104, 0.29548922181129456), stroke 1, (0.3585848808288574, 0.2429916262626648), stroke 1, (0.37338313460350037, 0.27713510394096375), stroke 1, (0.3694930076599121, 0.30178123712539 ...

# %%
mp_holistic=mp.solutions.holistic# TODO : Add add model of holistic
mp_drawing=mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

# %%
 with mp_holistic.Holistic (static_image_mode=True ,
            min_detection_confidence=0.3,min_tracking_confidence=0.5) as holisitc :
     
    #right_shoulder=[]
    #left_shoulder=[]
    right_wrist=[]
    left_wrist=[]
    points=[]
    # right_elbow=[]
    # left_elbow=[]
    # left_heel=[]
    # right_heel=[]
    # left_foot=[]
    # right_foot=[]
    # points=[]
    video = cv2.VideoCapture(0)
    image_width = 0
    image_height = 0
    while video.isOpened():
        ret, frame = video.read()

        # Recolor Feed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break   
        if ret == True:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        

            results = holisitc.process(image)
#             mp_drawing.draw_landmarks(
#             frame,
#             results.face_landmarks,
#             mp_holistic.FACEMESH_TESSELATION,
#             landmark_drawing_spec=None,
#             connection_drawing_spec=mp_drawing_styles
#             .get_default_face_mesh_tesselation_style())
#             mp_drawing.draw_landmarks(
#             frame, 
#             results.left_hand_landmarks, 
#             mp_holistic.HAND_CONNECTIONS)

#             mp_drawing.draw_landmarks(
#                 frame, 
#                 results.right_hand_landmarks, 
#                 mp_holistic.HAND_CONNECTIONS)
            
            if results.pose_landmarks:
                right_hand_landmarks = results.right_hand_landmarks
                left_hand_landmarks = results.left_hand_landmarks

                if right_hand_landmarks:
                    for landmark in right_hand_landmarks.landmark:
                        right_wrist.append(Point(landmark.x, landmark.y, 1))
                        points.append(Point(landmark.x, landmark.y, 1))

                if left_hand_landmarks:
                    for landmark in left_hand_landmarks.landmark:
                        left_wrist.append(Point(landmark.x, landmark.y, 2))
                        points.append(Point(landmark.x, landmark.y, 2))
                #print(points)
                #x = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width
                #y = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height
                #TODO: Open file and write coordinates
                #with open("points.txt", "a") as f:
                    #f.write(f"X: {x} Y: {y}\n")

            if results.left_hand_landmarks:
                
                    #x = hand_landmarks.landmark[8].x  
                    #y = hand_landmarks.landmark[8].y 
                    mp_drawing.draw_landmarks(
                    frame, 
                    results.left_hand_landmarks, 
                    mp_holistic.HAND_CONNECTIONS)
            
            if results.right_hand_landmarks:
                    #x = hand_landmarks.landmark[8].x  
                    #y = hand_landmarks.landmark[8].y 
                    mp_drawing.draw_landmarks(
                    frame,
                    results.right_hand_landmarks, 
                    mp_holistic.HAND_CONNECTIONS)
                    #con.send(bytes('{} {}'.format(x, y), encoding='utf-8'))#send
            #print(results)
            #print(points)
            image_height, image_width, _ = frame.shape
            if len(points) > 0:
                reco = Recognizer(classes)
                results = reco.recognize(points)
                #print(results)
                # Display the frame
                text = str(results)
                text_width, text_height = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)[0]
                cv2.putText(frame, text, (20, image_height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            cv2.imshow('Holistic Model', frame)
        # Wait for key event to exit
    # Release video capture device and close window
    video.release()
    cv2.destroyAllWindows()
# Out:
# ('Left_Hand_Detection', 0.5700133879270646)
# ('Left_Hand_Detection', 0.5700133879270646)
# ('Left_Hand_Detection', 0.5700133879270646)
# ('Left_Hand_Detection', 0.33459939039568953)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.3345993903956902)
# ('Left_Hand_Detection', 0.1979496183258378)
# ('Left_Hand_Detection', 0.1979496183258379)
# ('Left_Hand_Detection', 0.19794961832583824)
# ('Left_Hand_Detection', 0.19794961832583824)
# ('Left_Hand_Detection', 0.19794961832583824)
# (None, 0)
# (None, 0)
# (None, 0)
# ('Right_Hand_Detection', 0.10821566605919053)
# ('Right_Hand_Detection', 0.1082156660591922)
# ('Right_Hand_Detection', 0.10821566605919053)
# ('Right_Hand_Detection', 0.1082156660591913)
# ('Right_Hand_Detection', 0.10821566605919242)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# (None, 0)
# ('Right_Hand_Detection', 0.12524733256522202)
# ('Right_Hand_Detection', 0.08480095992866021)
# ('Right_Hand_Detection', 0.1757774563016692)
# ('Right_Hand_Detection', 0.17577745630166886)
# (None, 0)
# ('Right_Hand_Detection', 0.13298607336210755)
# ('Right_Hand_Detection', 0.18342415093741926)
# ('Right_Hand_Detection', 0.1960995245954188)
# ('Right_Hand_Detection', 0.12931549666422304)
# ('Right_Hand_Detection', 0.13450596062257802)
# ('Right_Hand_Detection', 0.1345059606225889)
# ('Right_Hand_Detection', 0.21661807958386048)
# ('Right_Hand_Detection', 0.24351175038282624)
# ('Right_Hand_Detection', 0.31639129151927536)
# ('Left_Hand_Detection', 0.026180877867913233)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
# ('Left_Hand_Detection', 0.026180877867910013)
